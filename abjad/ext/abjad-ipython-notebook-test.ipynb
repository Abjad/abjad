# %% [markdown]
# Welcome to the interactive test suite for Abjad's IPython extension.
#
# Before proceeding make sure you have the following tools available on your system:
#
# - IPython (http://ipython.org/)
# - Jupyter (http://jupyter.readthedocs.org/en/latest/index.html#)
# - timidity (http://timidity.sourceforge.net/)
#
# If you're reading this, you likely already have IPython and Jupyter installed.
#
# Timidity as available on \*nix installations via your package manager. On OSX, install via HomeBrew.
#
# Once the dependencies have been met, run each cell in this notebook in sequence. If any cell fails to run or otherwise generates an error message, investigate the cause and correct it.

# %%
from abjad import *

# %%
# %load_ext abjad.ext.ipython

# %%
staff = Staff("c'4 d'4 e'4 f'4")

# %% [markdown]
# Running the next cell should result in an HTML5 `<audio>` tag being displayed.
#
# Play the audio and verify that it matches the contents of `staff`.

# %%
play(staff)
# Out:
# <audio controls type="audio/ogg" src="data:audio/ogg;base64,...">

# %% [markdown]
# Running the next cell should result in a PNG being displayed.
#
# Verify that the PNG's appearance matches the contents of `staff`.

# %%
show(staff)
